# %%
# !python3.11 -m pip install pandas dash
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting dash
#   Downloading dash-2.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/laurentklopfenstein/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting plotly>=5.0.0 (from dash)
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting dash-html-components==2.0.0 (from dash)
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash)
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting typing-extensions>=4.1.1 (from dash)
#   Downloading typing_extensions-4.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting requests (from dash)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting retrying (from dash)
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /Users/laurentklopfenstein/Library/Python/3.11/lib/python/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from dash) (68.2.2)
# Collecting Jinja2>=3.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.6.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tenacity>=6.2.0 (from plotly>=5.0.0->dash)
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /Users/laurentklopfenstein/Library/Python/3.11/lib/python/site-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: six>=1.5 in /Users/laurentklopfenstein/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting MarkupSafe>=2.1.1 (from Werkzeug<3.1->dash)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting zipp>=0.5 (from importlib-metadata->dash)
#   Downloading zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->dash)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->dash)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->dash)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->dash)
#   Downloading certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading dash-2.17.0-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 15.1 MB/s eta 0:00:00a 0:00:01
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 12.8 MB/s eta 0:00:0000:0100:01
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 28.3 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading typing_extensions-4.12.1-py3-none-any.whl (37 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 19.4 MB/s eta 0:00:00
# Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.3 MB/s eta 0:00:00
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 15.8 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 11.7 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 18.1 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-macosx_10_9_universal2.whl (18 kB)
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Installing collected packages: pytz, dash-table, dash-html-components, dash-core-components, zipp, urllib3, tzdata, typing-extensions, tenacity, retrying, numpy, MarkupSafe, itsdangerous, idna, click, charset-normalizer, certifi, blinker, Werkzeug, requests, plotly, pandas, Jinja2, importlib-metadata, Flask, dash
# Successfully installed Flask-3.0.3 Jinja2-3.1.4 MarkupSafe-2.1.5 Werkzeug-3.0.3 blinker-1.8.2 certifi-2024.6.2 charset-normalizer-3.3.2 click-8.1.7 dash-2.17.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 idna-3.7 importlib-metadata-7.1.0 itsdangerous-2.2.0 numpy-1.26.4 pandas-2.2.2 plotly-5.22.0 pytz-2024.1 requests-2.32.3 retrying-1.3.4 tenacity-8.3.0 typing-extensions-4.12.1 tzdata-2024.1 urllib3-2.2.1 zipp-3.19.2
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
# --2024-06-04 20:52:59--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2476 (2.4K) [text/csv]
# Saving to: ‘spacex_launch_dash.csv.1’
#
# spacex_launch_dash. 100%[===================>]   2.42K  --.-KB/s    in 0s
#
# 2024-06-04 20:53:00 (124 MB/s) - ‘spacex_launch_dash.csv.1’ saved [2476/2476]

# %% [markdown]
# # Module 3 : Dash app python script

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
import plotly.graph_objects as go
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                html.Br(),
                                html.Div(dcc.Dropdown(id='site-dropdown',
                                    options=[
                                        {'label': 'All Sites', 'value': 'ALL'},
                                        {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                        {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                        {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                        {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}],
                                    value='ALL',
                                    placeholder="Select a Launch Site here",
                                    searchable=True
                                    )),
                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                html.Div(dcc.RangeSlider(id='payload-slider',
                                min=0, max=10000, step=1000,
                                marks={0: '0', 100: '100'},
                                value=[min_payload, max_payload])),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart'))
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df[filtered_df['class']==1], values='class', 
        names='Launch Site',
        title='Total Success Launches by site')
        return fig
    else:
        # return the outcomes piechart for a selected site
        site_df = filtered_df[filtered_df['Launch Site'] == entered_site]
        success_count = site_df[site_df['class']==1].shape[0]
        failure_count = site_df[site_df['class']==0].shape[0]
        fig = px.pie(values=[failure_count,success_count],
        names= ['Failure','Success'],
        title=f'Total Launch Outcomes for site {entered_site}')
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'),
                Input(component_id='payload-slider', component_property='value')])
def get_scatter_plot(entered_site, slider_range):
    filtered_df = spacex_df
    low, high = slider_range
    mask = (filtered_df['Payload Mass (kg)'] > low) & (filtered_df['Payload Mass (kg)'] < high)
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df[mask], x='Payload Mass (kg)', y='class',
        title='Correlation between Payload and Success for all Sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        fig = px.scatter(filtered_df[filtered_df['Launch Site'] == entered_site][mask], x='Payload Mass (kg)', y='class',
        color='Booster Version Category',
        title=f'Correlation between Payload and Success for site {entered_site}')
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Address already in use
# Port 8050 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/werkzeug/serving.py:746, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     745 try:
# --> 746     self.server_bind()
#     747     self.server_activate()
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/http/server.py:138, in HTTPServer.server_bind(self)
#     137 """Override server_bind to store the server name."""
# --> 138 socketserver.TCPServer.server_bind(self)
#     139 host, port = self.server_address[:2]
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/socketserver.py:466, in TCPServer.server_bind(self)
#     465     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466 self.socket.bind(self.server_address)
#     467 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 48] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 97
#      96 if __name__ == '__main__':
# ---> 97     app.run_server(debug=True)
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/dash/dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2218 """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219 future version. We recommend using `app.run` instead.
#    2220
#    2221 See `app.run` for usage information.
#    2222 """
# -> 2223 self.run(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/dash/dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/dash/_jupyter.py:332, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     330 err_q = queue.Queue()
# --> 332 server = make_server(host, port, app.server, threaded=True, processes=0)
#     333 logging.getLogger("werkzeug").setLevel(logging.ERROR)
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/werkzeug/serving.py:917, in make_server(host, port, app, threaded, processes, request_handler, passthrough_errors, ssl_context, fd)
#     916 if threaded:
# --> 917     return ThreadedWSGIServer(
#     918         host, port, app, request_handler, passthrough_errors, ssl_context, fd=fd
#     919     )
#     921 if processes > 1:
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/werkzeug/serving.py:769, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     763             print(
#     764                 "On macOS, try disabling the 'AirPlay Receiver' service"
#     765                 " from System Preferences -> General -> AirDrop & Handoff.",
#     766                 file=sys.stderr,
#     767             )
# --> 769     sys.exit(1)
#     770 except BaseException:
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/.pyenv/versions/3.9.2/envs/lpp3ed/lib/python3.9/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
